# %% [markdown]
# ## Template to create ERKER_v1.3_Import_Template.csv

# %%
from cmath import nan
from tkinter import Y
import unittest
import pandas as pd
import numpy as np
import datetime
from datetime import datetime, date
from datetime import timedelta
import os
import csv
from dateutil.relativedelta import relativedelta

# %%
ERKER_v1p3_list = {

    "record_id": np.nan,
    "redcap_event_name": np.nan,
    "redcap_repeat_instrument": np.nan,
    "redcap_repeat_instance": np.nan,
    "sct_422549004": np.nan,
    "sct_399423000": np.nan,
    # 2. Persönliche Angaben
    "sct_184099003_y": np.nan,
    "sct_281053000": np.nan,
    "sct_263495000": np.nan,
    "sct_315354004": np.nan,
    "sct_397731000": np.nan,
    # 3. Patientenstatus
    "ln_67162_8": np.nan,
    "sct_399753006": np.nan,
    "sct_410598002": np.nan,
    "sct_184305005_rd": np.nan,
    "sct_16100001": np.nan,
    "sct_16100001_source": np.nan,
    # 4. Behandlungsverlauf
    "sct_769681006": np.nan,
    "sct_3457005": np.nan,
    "sct_276239002_aim": np.nan,
    "sct_424850005": np.nan,
    # 5. Krankheitsverlauf
    "sct_424850005_y": np.nan,
    "sct_424850005_m": np.nan,
    "sct_424850005_d": np.nan,
    "sct_423493009": np.nan,
    "sct_423493009_y": np.nan,
    "sct_423493009_m": np.nan,
    "sct_423493009_d": np.nan,
    "sct_717800004": np.nan,
    "sct_412726003": np.nan,
    "sct_64245008": np.nan,
    "sct_125679009_proposit": np.nan,
    "sct_842009": np.nan,
    # 6.1 Hauptdiagnose
    "sct_439401001_orpha": np.nan,
    "sct_439401001_orpha_sub": np.nan,
    "sct_439401001_icd10gm": np.nan,
    "sct_439401001_alphaid": np.nan,
    "sct_439401001_alphaidstr": np.nan,
    "sct_442083009_d": np.nan,
    "sct_432213005": np.nan,
    "sct_263493007": np.nan,
    "sct_116694002": np.nan,
    "sct_246454002": np.nan,
    "sct_439401001_ver": np.nan,
    "sct_103330002": np.nan,
    "sct_41769001_orpha": np.nan,
    "sct_41769001_icd10": np.nan,
    "sct_439401001_val": np.nan,
    "sct_39154008_hpo": np.nan,
    "sct_439401001_gen_biom_val": np.nan,
    "sct_439401001_biom": np.nan,
    "sct_406522009": np.nan,
    "ln_55198_6": np.nan,
    "sct_255404009_mitoch": np.nan,
    "sct_277132007": np.nan,
    "sct_277132007_other": np.nan,
    "sct_439401001_gen_val": np.nan,
    # 6.2 Genetischer Befund
    "ln_ll4048_6": np.nan,
    "sct_439401001_omim_g": np.nan,
    "sct_439401001_omim_p": np.nan,
    "sct_55446002_str_1": np.nan,
    "ln_81290_9_1": np.nan,
    "ln_48004_6_1": np.nan,
    "ln_48005_3_1": np.nan,
    "ln_47999_8_dna_hgnc_1": np.nan,
    "ln_ll3781_1_1": np.nan,
    "ln_48019_4_1": np.nan,
    "ln_ll4034_6_1": np.nan,
    "ln_93044_6_1": np.nan,
    "sct_55446002_str_2": np.nan,
    "ln_81290_9_2": np.nan,
    "ln_48004_6_2": np.nan,
    "ln_48005_3_2": np.nan,
    "ln_47999_8_dna_hgnc_2": np.nan,
    "ln_ll3781_1_2": np.nan,
    "ln_48019_4_2": np.nan,
    "ln_ll4034_6_2": np.nan,
    "ln_93044_6_2": np.nan,
    "sct_55446002_str_3": np.nan,
    "ln_81290_9_3": np.nan,
    "ln_48004_6_3": np.nan,
    "ln_48005_3_3": np.nan,
    "ln_47999_8_dna_hgnc_3": np.nan,
    "sct_85097005_18_orpha": np.nan,
    "sct_85097005_18_icd10gm": np.nan,
    "sct_85097005_18_date": np.nan,
    "sct_85097005_19_orpha": np.nan,
    "sct_85097005_19_icd10gm": np.nan,
    "sct_85097005_19_date": np.nan,
    "sct_85097005_20_orpha": np.nan,
    "sct_85097005_20_icd10gm": np.nan,
    "sct_85097005_20_date": np.nan,
    # 6.4 Phänotypisierung
    "sct_8116006_1": np.nan,
    "sct_8116006_2": np.nan,
    "sct_8116006_3": np.nan,
    "sct_8116006_4": np.nan,
    "sct_8116006_5": np.nan,
    "sct_8116006_6": np.nan,
    "sct_8116006_7": np.nan,
    "sct_8116006_8": np.nan,
    "sct_8116006_9": np.nan,
    "sct_8116006_10": np.nan,
    "sct_8116006_11": np.nan,
    "sct_8116006_12": np.nan,
    "sct_8116006_13": np.nan,
    "sct_8116006_14": np.nan,
    "sct_8116006_15": np.nan,
    "sct_8116006_16": np.nan,
    "sct_8116006_17": np.nan,
    "sct_8116006_18": np.nan,
    "sct_8116006_19": np.nan,
    "sct_8116006_20": np.nan,
    "sct_8116006_21": np.nan,
    "sct_8116006_22": np.nan,
    "sct_8116006_23": np.nan,
    "sct_8116006_24": np.nan,
    "sct_8116006_25": np.nan,
    "sct_8116006_26": np.nan,
    "sct_8116006_27": np.nan,
    "sct_8116006_28": np.nan,
    "sct_8116006_29": np.nan,
    "sct_8116006_30": np.nan,
    # 6.5 Familienanamnese
    "sct_72705000_rd": np.nan,
    "sct_160430005": np.nan,
    "sct_72705000_age": np.nan,
    "sct_160430005_age": np.nan,
    "sct_66839005_rd": np.nan,
    "sct_160436004": np.nan,
    "sct_66839005_age": np.nan,
    "sct_160436004_age": np.nan,
    "sct_82101005_rd": np.nan,
    "sct_82101005_1_yob": np.nan,
    "sct_82101005_1_gender": np.nan,
    "sct_82101005_2_yob": np.nan,
    "sct_82101005_2_gender": np.nan,
    "sct_82101005_3_yob": np.nan,
    "sct_82101005_3_gender": np.nan,
    "sct_82101005_4_yob": np.nan,
    "sct_82101005_4_gender": np.nan,
    "sct_82101005_5_yob": np.nan,
    "sct_82101005_5_gender": np.nan,
    "sct_82101005_6_yob": np.nan,
    "sct_82101005_6_gender": np.nan,
    "sct_82101005_7_yob": np.nan,
    "sct_82101005_7_gender": np.nan,
    "sct_82101005_8_yob": np.nan,
    "sct_82101005_8_gender": np.nan,
    "sct_82101005_9_yob": np.nan,
    "sct_82101005_9_gender": np.nan,
    "sct_82101005_10_yob": np.nan,
    "sct_82101005_10_gender": np.nan,
    # 7. Einwilligung Daten
    "sct_309370004_forschung": np.nan,
    "sct_309370004_narse": np.nan,
    "sct_441898007_data": np.nan,
    "sct_441898007_eu": np.nan,
    "sct_441898007_int": np.nan,
    "sct_441898007_res": np.nan,
    "sct_441898007_gen": np.nan,
    "sct_441898007_case": np.nan,
    "sct_123038009": np.nan,
    "sct_840566006": np.nan,
    "sct_840566006_specific": np.nan,
    "sct_21134002_class": np.nan,
    "sct_21134002_score": np.nan,
    "erker_v13_complete": np.nan,

}

# %% [markdown]
# #### Create ERKER_v1.3 compatible .csv file

# %%
ERKER_1p3_df = pd.DataFrame(data=[ERKER_v1p3_list])

## insert 'path' to create the .csv

# ERKER_1p3_df.to_csv('path.csv', index = False, sep=',', mode = 'w')
